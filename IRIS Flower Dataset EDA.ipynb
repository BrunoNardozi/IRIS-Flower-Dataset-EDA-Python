# %% [markdown]
# # IRIS Flower Dataset EDA

# %% [markdown]
# This code is an example of an Exploratory Data Analysis on the IRIS flowers dataset

# %%
# install and import libraries

! pip install pandas
import pandas as pd
# !pip install matplotlib
import matplotlib.pyplot as plt
# !pip install seaborn
import seaborn as sns
# Out:
# ...
# C:\Users\bruno\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ...

# %%
# load the dataset

df=pd.read_csv(IRIS.csv')   # add path to .csv

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# check for Na

df.isna().sum().sort_values(ascending=False)
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Identify duplicates

df[df.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
# Count entries by species

print(df['species'].value_counts().to_string())
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50

# %%
df.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width      species
# count     150.000000   150.000000    150.000000   150.000000          150
# unique           NaN          NaN           NaN          NaN            3
# top              NaN          NaN           NaN          NaN  Iris-setosa
# freq             NaN          NaN           NaN          NaN           50
# mean        5.843333     3.054000      3.758667     1.198667          NaN
# std         0.828066     0.433594      1.764420     0.763161          NaN
# min         4.300000     2.000000      1.000000     0.100000          NaN
# 25%         5.100000     2.800000      1.600000     0.300000          NaN
# 50%         5.800000     3.000000      4.350000     1.300000          NaN
# 75%         6.400000     3.300000      5.100000     1.800000          NaN
# max         7.900000     4.400000      6.900000     2.500000          NaN

# %% [markdown]
# # Univariate Analysis

# %%
# Histograms 

fig, axes = plt.subplots(2, 2, figsize=(8,6))

axes[0,0].set_title("Sepal Length")
axes[0,0].hist(df['sepal_length'], bins=20)

axes[0,1].set_title("Sepal Width")
axes[0,1].hist(df['sepal_width'], bins=20);

axes[1,0].set_title("Petal Length")
axes[1,0].hist(df['petal_length'], bins=20);

axes[1,1].set_title("Petal Width")
axes[1,1].hist(df['petal_width'], bins=20);

plt.show()

# %% [markdown]
# . Sepal Lenght and Width have a relative normal distribution
# . Petal Lenght and Width have gaps in their distributions

# %%
# Boxplots 

plt.figure(figsize=(10, 8))

plt.subplot(221)
sns.boxplot(x="species", y='sepal_length', data=df)

plt.subplot(222)
sns.boxplot(x="species", y='sepal_width', data=df)

plt.subplot(223)
sns.boxplot(x="species", y='petal_length', data=df)

plt.subplot(224)
sns.boxplot(x="species", y='petal_width', data=df)

plt.tight_layout()
plt.show()

# %% [markdown]
# . Iris-setosa petals are smaller than other flower species. Their sepals are usually thinner but longer. Their petals have the most homogeneous size.
# . Iris-virginica petals are usually bigger than other flower species. Their sepals are usually the longest but not the widest.
# . Iris-versicolor sepals are usually thinner than other flower species.

# %% [markdown]
# # Multivariate Analysis

# %%
# Scatterplots

sns.set_style('whitegrid')
sns.pairplot(df,hue='species',height=3)
plt.show()
# Out:
# C:\Users\bruno\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bruno\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\bruno\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Overlapping histograms

plot = sns.FacetGrid(df, hue="species")
plot.map(sns.histplot, "sepal_length").add_legend()

plot = sns.FacetGrid(df, hue="species")
plot.map(sns.histplot, "sepal_width").add_legend()

plot = sns.FacetGrid(df, hue="species")
plot.map(sns.histplot, "petal_length").add_legend()

plot = sns.FacetGrid(df, hue="species")
plot.map(sns.histplot, "petal_width").add_legend()

plt.show()
# Out:
# C:\Users\bruno\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bruno\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bruno\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# . Distinction of flower species based on sepal lenght and widht will be more dificult because of the overlapping values.
# . Iris-setosa could easily be identified based on petal lenght and width since there's no overlapping values.

# %%
sns.heatmap(df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].corr(method='pearson'), annot = True, cmap='coolwarm');

plt.show()

# %% [markdown]
# . Strong positive correlation between petal length and width. This means that all flower species have similar petal shapes.
# . Strong positive correlation between sepal length and petal length and width.
